-- %% [markdown]
-- # [dbo].[TBL_NCC]

-- %%
USE [Linq]
GO

-- %%
/****** Object:  Table [dbo].[TBL_NCC]    Script Date: 3/31/2023 1:43:07 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TBL_NCC](
	[mancc] [nchar](10) NOT NULL,
	[tenncc] [nvarchar](50) NULL,
 CONSTRAINT [PK_TBL_NCC] PRIMARY KEY CLUSTERED 
(
	[mancc] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TBL_SANPAHM]

-- %%
/****** Object:  Table [dbo].[TBL_SANPAHM]    Script Date: 3/31/2023 1:43:07 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TBL_SANPAHM](
	[mahang] [nchar](10) NOT NULL,
	[tenhang] [nvarchar](20) NULL,
	[mancc] [nchar](10) NULL,
	[soluong] [int] NULL,
	[donhangnhap] [nvarchar](50) NULL,
 CONSTRAINT [PK_TBL_SANPAHM] PRIMARY KEY CLUSTERED 
(
	[mahang] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TBL_NCC]

-- %%
INSERT [dbo].[TBL_NCC] ([mancc], [tenncc]) VALUES (N'ph3       ', N'ta tuan anh')
INSERT [dbo].[TBL_NCC] ([mancc], [tenncc]) VALUES (N'ph4       ', N'tran quang khai')
INSERT [dbo].[TBL_NCC] ([mancc], [tenncc]) VALUES (N'ph5       ', N'phung duy tien')
INSERT [dbo].[TBL_NCC] ([mancc], [tenncc]) VALUES (N'ph8       ', N'pham minh long')
GO

-- %% [markdown]
-- # [dbo].[TBL_SANPAHM]

-- %%
INSERT [dbo].[TBL_SANPAHM] ([mahang], [tenhang], [mancc], [soluong], [donhangnhap]) VALUES (N'ph41      ', N'nhuom toc', N'ph4       ', 2, N'7')
GO

-- %% [markdown]
-- # [FK_TBL_SANPAHM_TBL_NCC]

-- %%
ALTER TABLE [dbo].[TBL_SANPAHM]  WITH CHECK ADD  CONSTRAINT [FK_TBL_SANPAHM_TBL_NCC] FOREIGN KEY([mancc])
REFERENCES [dbo].[TBL_NCC] ([mancc])
GO
ALTER TABLE [dbo].[TBL_SANPAHM] CHECK CONSTRAINT [FK_TBL_SANPAHM_TBL_NCC]
GO
